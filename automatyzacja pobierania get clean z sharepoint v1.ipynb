# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import os

# %%
driver = webdriver.Chrome()

# %%
# GET CELAN EUKF
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-EUKF.xlsx')
driver.refresh()
time.sleep(2)

# GET CELAN PESA
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-PESA.xlsx')
time.sleep(2)

# GET CELAN PESB
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-PESB.xlsx')
time.sleep(2)

# GET CELAN PUKC
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-PUKC.xlsx')
time.sleep(2)

# GET CELAN PUKG
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-PUKG.xlsx')
time.sleep(2)

# GET CELAN XDEA
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XDEA.xlsx')
time.sleep(2)

# GET CELAN XDEB
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XDEB.xlsx')
time.sleep(2)

# GET CELAN XDEH
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XDEH.xlsx')
time.sleep(2)

# GET CELAN XDEI
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XDEI.xlsx')
time.sleep(2)

# GET CELAN XDEJ
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XDEJ.xlsx')
time.sleep(2)

# GET CELAN XDEQ
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XDEQ.xlsx')
time.sleep(2)

# GET CELAN XDES
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XDES.xlsx')
time.sleep(2)

# GET CELAN XDET
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XDET.xlsx')
time.sleep(2)

# GET CELAN XDEU
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XDEU.xlsx')
time.sleep(2)

# GET CELAN XDEV
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XDEV.xlsx')
time.sleep(2)

# GET CELAN XDEW
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XDEW.xlsx')
time.sleep(2)

# GET CELAN XDEY
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XDEY.xlsx')
time.sleep(2)

# GET CELAN XDEZ
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XDEZ.xlsx')
time.sleep(2)

# GET CELAN XESA
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XESA.xlsx')
time.sleep(2)

# GET CELAN XESC
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XESC.xlsx')
time.sleep(2)

# GET CELAN XESE
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XESE.xlsx')
time.sleep(2)

# GET CELAN XESF
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XESF.xlsx')
time.sleep(2)

# GET CELAN XFRE
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XFRE.xlsx')
time.sleep(2)

# GET CELAN XFRF
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XFRF.xlsx')
time.sleep(2)

# GET CELAN XFRG
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XFRG.xlsx')
time.sleep(2)

# GET CELAN XFRH
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XFRH.xlsx')
time.sleep(2)

# GET CELAN XFRI
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XFRI.xlsx')
time.sleep(2)

# GET CELAN XFRJ
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XFRJ.xlsx')
time.sleep(2)

# GET CELAN XFRK
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XFRK.xlsx')
time.sleep(2)

# GET CELAN XFRL
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XFRL.xlsx')
time.sleep(2)

# GET CELAN XFRN
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XFRN.xlsx')
time.sleep(2)

# GET CELAN XFRO
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XFRO.xlsx')
time.sleep(2)

# GET CELAN XFRZ
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XFRZ.xlsx')
time.sleep(2)

# GET CELAN XIBA
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XIBA.xlsx')
time.sleep(2)

# GET CELAN XITC
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XITC.xlsx')
time.sleep(2)

# GET CELAN XITD
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XITD.xlsx')
time.sleep(2)

# GET CELAN XITF
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XITF.xlsx')
time.sleep(2)

# GET CELAN XITG
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XITG.xlsx')
time.sleep(2)

# GET CELAN XITH
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XITH.xlsx')
time.sleep(2)

# GET CELAN XITI
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XITI.xlsx')
time.sleep(2)

# GET CELAN XITJ
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XITJ.xlsx')
time.sleep(2)

# GET CELAN XITK
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XITK.xlsx')
time.sleep(2)

# GET CELAN XLP1
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XLP1.xlsx')
time.sleep(2)

# GET CELAN XPLA
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XPLA.xlsx')
time.sleep(2)

# GET CELAN XPLB
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XPLB.xlsx')
time.sleep(2)

# GET CELAN XPLC
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XPLC.xlsx')
time.sleep(2)

# GET CELAN XPLD
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XPLD.xlsx')
time.sleep(2)

# GET CELAN XPLE
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XPLE.xlsx')
time.sleep(2)

# GET CELAN XTRA
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XTRA.xlsx')
time.sleep(2)

# GET CELAN XTRB
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XTRB.xlsx')
time.sleep(2)

# GET CELAN XUKA
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XUKA.xlsx')
time.sleep(2)

# GET CELAN XUKD
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XUKD.xlsx')
time.sleep(2)

# GET CELAN XUKD-1
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XUKD-1.xlsx')
time.sleep(2)

# GET CELAN XUKK
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XUKK.xlsx')
time.sleep(2)

# GET CELAN XUKN
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XUKN.xlsx')
time.sleep(2)

# GET CELAN XUKO
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XUKO.xlsx')
time.sleep(2)

# GET CELAN XUKP
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XUKP.xlsx')
time.sleep(2)

# GET CELAN XUKR
driver.get('https://somesite.amazon.com/sites/EU_External_Fulfillment_Network/EU%20EF%20Data%20Reseach/Get%20Clean/Get%20Clean%20Details/Get_Clean_Details-XUKR.xlsx')
time.sleep(2)

# %%
driver.quit()
print(f"IT'S ALIVE! :)")
# Out:
# IT'S ALIVE! :)
